# %%
import requests as req
import re
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import time
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../src')

# %%
ubica_rest = pd.read_csv('../datos/ubica_rest.csv')

# %%
ubica_rest.head()
# Out:
#         restaurante                               ubicacion  \
# 0    Yakiniku Rikyu  P.º de la Castellana, 15, 28046 Madrid
# 1          marmitón        C. de las Aguas, 6, 28005 Madrid
# 2  Vinoteca Moratín         C. de Moratín, 36, 28014 Madrid
# 3     Pilar Akaneya      C. de Espronceda, 33, 28003 Madrid
# 4             Gioia   C. de San Bartolomé, 23, 28004 Madrid
#
#                                      Lat&Lon
# 0                    (40.4280979, -3.690173)
# 1           (40.4108219, -3.712107746868964)
# 2  (40.412472050000005, -3.6954412113077497)
# 3                    (40.4405573, -3.696109)
# 4                   (40.4221651, -3.6983792)

# %%
data_rest = pd.read_csv('../datos/data_rest.csv')

# %%
data_rest.head()
# Out:
#         restaurante    gastronomia precio         opinion       reseña
# 0    Yakiniku Rikyu       Japonesa  Medio   267 opiniones  Patrocinado
# 1          marmitón   Mediterránea  Medio    89 opiniones     MICHELIN
# 2  Vinoteca Moratín  Internacional  Medio  1221 opiniones     MICHELIN
# 3     Pilar Akaneya       Japonesa   Alto   276 opiniones     MICHELIN
# 4             Gioia       Italiana  Medio   387 opiniones     MICHELIN

# %%
# Realizo el merge de los DataFrames
merged_data = pd.merge(data_rest, ubica_rest[['restaurante', 'ubicacion', 'Lat&Lon']], on='restaurante', how='left')

# %%
merged_data.head(15)
# Out:
#                     restaurante    gastronomia precio         opinion  \
# 0                Yakiniku Rikyu       Japonesa  Medio   267 opiniones
# 1                      marmitón   Mediterránea  Medio    89 opiniones
# 2              Vinoteca Moratín  Internacional  Medio  1221 opiniones
# 3                 Pilar Akaneya       Japonesa   Alto   276 opiniones
# 4                         Gioia       Italiana  Medio   387 opiniones
# 5                Noi Ristorante       Italiana  Medio   244 opiniones
# 6   Mudrá Plant Based Recoletos  Internacional  Medio    67 opiniones
# 7           La MaMá Restaurante   Mediterránea  Medio   225 opiniones
# 8                        Sisapo   Mediterránea  Medio    71 opiniones
# 9             RECREO Espartinas   Mediterránea  Medio   366 opiniones
# 10                       Miyama       Japonesa   Alto   837 opiniones
# 11                       Deessa   Mediterránea   Alto    52 opiniones
# 12                Hotaru Madrid       Japonesa   Alto   199 opiniones
# 13              Yugo the Bunker       Japonesa   Alto   342 opiniones
# 14                        Coque  Internacional   Alto   476 opiniones
#
#          reseña                                   ubicacion  \
# 0   Patrocinado      P.º de la Castellana, 15, 28046 Madrid
# 1      MICHELIN            C. de las Aguas, 6, 28005 Madrid
# 2      MICHELIN             C. de Moratín, 36, 28014 Madrid
# 3      MICHELIN          C. de Espronceda, 33, 28003 Madrid
# 4      MICHELIN       C. de San Bartolomé, 23, 28004 Madrid
# 5      MICHELIN            C. de Recoletos, 6, 28001 Madrid
# 6      MICHELIN           C. de Recoletos, 13, 28001 Madrid
# 7      MICHELIN  6 bis, Parque, Av. de Brasil, 28020 Madrid
# 8      MICHELIN           C. de Trafalgar, 14, 28010 Madrid
# 9      MICHELIN        C. de Espartinas, Nº 5, 28001 Madrid
# 10     MICHELIN                                         NaN
# 11     MICHELIN          Pl. de la Lealtad, 5, 28014 Madrid
# 12     MICHELIN              C. de Alcalá, 99, 28009 Madrid
# 13     MICHELIN          Calle de San Blas, 4, 28014 Madrid
# 14     MICHELIN                                         NaN
#
#                                       Lat&Lon
# 0                     (40.4280979, -3.690173)
# 1            (40.4108219, -3.712107746868964)
# 2   (40.412472050000005, -3.6954412113077497)
# 3                     (40.4405573, -3.696109)
# 4                    (40.4221651, -3.6983792)
# 5                    (40.4220139, -3.6906004)
# 6                    (40.4218211, -3.6898244)
# 7                                         NaN
# 8                    (40.4318711, -3.7004566)
# 9                                         NaN
# 10                      (44.933143, 7.540121)
# 11          (40.41555015, -3.692725530645917)
# 12                    (40.421502, -3.6834669)
# 13                    (40.410375, -3.6938335)
# 14                      (44.933143, 7.540121)

# %%
merged_data['ubicacion'][10]
# Out:
# nan

# %%
merged_data['ubicacion'] = merged_data['ubicacion'].fillna('')

# %%
merged_data.head(15)
# Out:
#                     restaurante    gastronomia precio         opinion  \
# 0                Yakiniku Rikyu       Japonesa  Medio   267 opiniones
# 1                      marmitón   Mediterránea  Medio    89 opiniones
# 2              Vinoteca Moratín  Internacional  Medio  1221 opiniones
# 3                 Pilar Akaneya       Japonesa   Alto   276 opiniones
# 4                         Gioia       Italiana  Medio   387 opiniones
# 5                Noi Ristorante       Italiana  Medio   244 opiniones
# 6   Mudrá Plant Based Recoletos  Internacional  Medio    67 opiniones
# 7           La MaMá Restaurante   Mediterránea  Medio   225 opiniones
# 8                        Sisapo   Mediterránea  Medio    71 opiniones
# 9             RECREO Espartinas   Mediterránea  Medio   366 opiniones
# 10                       Miyama       Japonesa   Alto   837 opiniones
# 11                       Deessa   Mediterránea   Alto    52 opiniones
# 12                Hotaru Madrid       Japonesa   Alto   199 opiniones
# 13              Yugo the Bunker       Japonesa   Alto   342 opiniones
# 14                        Coque  Internacional   Alto   476 opiniones
#
#          reseña                                   ubicacion  \
# 0   Patrocinado      P.º de la Castellana, 15, 28046 Madrid
# 1      MICHELIN            C. de las Aguas, 6, 28005 Madrid
# 2      MICHELIN             C. de Moratín, 36, 28014 Madrid
# 3      MICHELIN          C. de Espronceda, 33, 28003 Madrid
# 4      MICHELIN       C. de San Bartolomé, 23, 28004 Madrid
# 5      MICHELIN            C. de Recoletos, 6, 28001 Madrid
# 6      MICHELIN           C. de Recoletos, 13, 28001 Madrid
# 7      MICHELIN  6 bis, Parque, Av. de Brasil, 28020 Madrid
# 8      MICHELIN           C. de Trafalgar, 14, 28010 Madrid
# 9      MICHELIN        C. de Espartinas, Nº 5, 28001 Madrid
# 10     MICHELIN
# 11     MICHELIN          Pl. de la Lealtad, 5, 28014 Madrid
# 12     MICHELIN              C. de Alcalá, 99, 28009 Madrid
# 13     MICHELIN          Calle de San Blas, 4, 28014 Madrid
# 14     MICHELIN
#
#                                       Lat&Lon
# 0                     (40.4280979, -3.690173)
# 1            (40.4108219, -3.712107746868964)
# 2   (40.412472050000005, -3.6954412113077497)
# 3                     (40.4405573, -3.696109)
# 4                    (40.4221651, -3.6983792)
# 5                    (40.4220139, -3.6906004)
# 6                    (40.4218211, -3.6898244)
# 7                                         NaN
# 8                    (40.4318711, -3.7004566)
# 9                                         NaN
# 10                      (44.933143, 7.540121)
# 11          (40.41555015, -3.692725530645917)
# 12                    (40.421502, -3.6834669)
# 13                    (40.410375, -3.6938335)
# 14                      (44.933143, 7.540121)

# %%
merged_data.to_csv('../datos/restaurant_def.csv', index=False, encoding='utf-8')

# %%
merged_data.head(10)
# Out:
#                    restaurante    gastronomia precio         opinion  \
# 0               Yakiniku Rikyu       Japonesa  Medio   267 opiniones
# 1                     marmitón   Mediterránea  Medio    89 opiniones
# 2             Vinoteca Moratín  Internacional  Medio  1221 opiniones
# 3                Pilar Akaneya       Japonesa   Alto   276 opiniones
# 4                        Gioia       Italiana  Medio   387 opiniones
# 5               Noi Ristorante       Italiana  Medio   244 opiniones
# 6  Mudrá Plant Based Recoletos  Internacional  Medio    67 opiniones
# 7          La MaMá Restaurante   Mediterránea  Medio   225 opiniones
# 8                       Sisapo   Mediterránea  Medio    71 opiniones
# 9            RECREO Espartinas   Mediterránea  Medio   366 opiniones
#
#         reseña                                   ubicacion  \
# 0  Patrocinado      P.º de la Castellana, 15, 28046 Madrid
# 1     MICHELIN            C. de las Aguas, 6, 28005 Madrid
# 2     MICHELIN             C. de Moratín, 36, 28014 Madrid
# 3     MICHELIN          C. de Espronceda, 33, 28003 Madrid
# 4     MICHELIN       C. de San Bartolomé, 23, 28004 Madrid
# 5     MICHELIN            C. de Recoletos, 6, 28001 Madrid
# 6     MICHELIN           C. de Recoletos, 13, 28001 Madrid
# 7     MICHELIN  6 bis, Parque, Av. de Brasil, 28020 Madrid
# 8     MICHELIN           C. de Trafalgar, 14, 28010 Madrid
# 9     MICHELIN        C. de Espartinas, Nº 5, 28001 Madrid
#
#                                      Lat&Lon
# 0                    (40.4280979, -3.690173)
# 1           (40.4108219, -3.712107746868964)
# 2  (40.412472050000005, -3.6954412113077497)
# 3                    (40.4405573, -3.696109)
# 4                   (40.4221651, -3.6983792)
# 5                   (40.4220139, -3.6906004)
# 6                   (40.4218211, -3.6898244)
# 7                                        NaN
# 8                   (40.4318711, -3.7004566)
# 9                                        NaN

# %%
restaurantes = merged_data.copy()

# %%
restaurantes['Lat&Lon'] = restaurantes['Lat&Lon'].astype(str)


lat_lon_pattern = r'\(([^,]+), ([^)]+)\)'
restaurantes[['lat', 'long']] = restaurantes['Lat&Lon'].str.extract(lat_lon_pattern)

# %%
# Convierte las nuevas columnas a tipos numéricos si es necesario
restaurantes[['lat', 'long']] = restaurantes[['lat', 'long']].apply(pd.to_numeric, errors='coerce')

# Elimina la columna "Lat&Lon"
restaurantes = restaurantes.drop('Lat&Lon', axis=1)

# %%
restaurantes.head(20)
# Out:
#                     restaurante    gastronomia precio  \
# 0                Yakiniku Rikyu       Japonesa  Medio
# 1                      marmitón   Mediterránea  Medio
# 2              Vinoteca Moratín  Internacional  Medio
# 3                 Pilar Akaneya       Japonesa   Alto
# 4                         Gioia       Italiana  Medio
# 5                Noi Ristorante       Italiana  Medio
# 6   Mudrá Plant Based Recoletos  Internacional  Medio
# 7           La MaMá Restaurante   Mediterránea  Medio
# 8                        Sisapo   Mediterránea  Medio
# 9             RECREO Espartinas   Mediterránea  Medio
# 10                       Miyama       Japonesa   Alto
# 11                       Deessa   Mediterránea   Alto
# 12                Hotaru Madrid       Japonesa   Alto
# 13              Yugo the Bunker       Japonesa   Alto
# 14                        Coque  Internacional   Alto
# 15   El pedrusco de Aldealcorvo  Internacional  Medio
# 16         KABUKI WELLINGTON SL       Japonesa   Alto
# 17                       Kabuki       Japonesa   Alto
# 18           Restaurante Lakasa   Mediterránea  Medio
# 19                      Bardero   Mediterránea  Medio
#
#                              opinion                                   reseña  \
# 0                      267 opiniones                              Patrocinado
# 1                       89 opiniones                                 MICHELIN
# 2                     1221 opiniones                                 MICHELIN
# 3                      276 opiniones                                 MICHELIN
# 4                      387 opiniones                                 MICHELIN
# 5                      244 opiniones                                 MICHELIN
# 6                       67 opiniones                                 MICHELIN
# 7                      225 opiniones                                 MICHELIN
# 8                       71 opiniones                                 MICHELIN
# 9                      366 opiniones                                 MICHELIN
# 10                     837 opiniones                                 MICHELIN
# 11                      52 opiniones                                 MICHELIN
# 12                     199 opiniones                                 MICHELIN
# 13                     342 opiniones                                 MICHELIN
# 14                     476 opiniones                                 MICHELIN
# 15  223 opinionesCierra en 6 minutos                                 MICHELIN
# 16                     974 opiniones                                 MICHELIN
# 17                     725 opiniones                                 MICHELIN
# 18                    1161 opiniones                                 MICHELIN
# 19                     106 opiniones  Comida espectacular por 37€ por persona
#
#                                             ubicacion        lat      long
# 0              P.º de la Castellana, 15, 28046 Madrid  40.428098 -3.690173
# 1                    C. de las Aguas, 6, 28005 Madrid  40.410822 -3.712108
# 2                     C. de Moratín, 36, 28014 Madrid  40.412472 -3.695441
# 3                  C. de Espronceda, 33, 28003 Madrid  40.440557 -3.696109
# 4               C. de San Bartolomé, 23, 28004 Madrid  40.422165 -3.698379
# 5                    C. de Recoletos, 6, 28001 Madrid  40.422014 -3.690600
# 6                   C. de Recoletos, 13, 28001 Madrid  40.421821 -3.689824
# 7          6 bis, Parque, Av. de Brasil, 28020 Madrid        NaN       NaN
# 8                   C. de Trafalgar, 14, 28010 Madrid  40.431871 -3.700457
# 9                C. de Espartinas, Nº 5, 28001 Madrid        NaN       NaN
# 10                                                     44.933143  7.540121
# 11                 Pl. de la Lealtad, 5, 28014 Madrid  40.415550 -3.692726
# 12                     C. de Alcalá, 99, 28009 Madrid  40.421502 -3.683467
# 13                 Calle de San Blas, 4, 28014 Madrid  40.410375 -3.693834
# 14                                                     44.933143  7.540121
# 15            C. de Juan de Austria, 27, 28010 Madrid  40.433943 -3.700049
# 16                   C. de Velázquez, 6, 28001 Madrid  40.421771 -3.684182
# 17                                                     44.933143  7.540121
# 18  Pl. del Descubridor Diego de Ordás, 1, 28003 M...  40.440880 -3.700779
# 19             Palos de la Frontera, 11, 28012 Madrid  40.403976 -3.694602

# %%
restaurantes['lat'] = restaurantes['lat'].fillna('')
restaurantes.loc[restaurantes['ubicacion'] == '', 'lat'] = ''

# %%
restaurantes['long'] = restaurantes['long'].fillna('')
restaurantes.loc[restaurantes['ubicacion'] == '', 'long'] = ''

# %%
restaurantes.tail(10)
# Out:
#                           restaurante            gastronomia precio  \
# 290                      nonsolocaffé               Italiana  Medio
# 291                   Solito Taqueria  Mexicana€€ - €€€Carta  Medio
# 292               Restaurante La Rita          Internacional  Medio
# 293                           Asia Te                  China  Medio
# 294                    Diaz y Larrouy           Mediterránea  Medio
# 295                    Mad by Robleño           Mediterránea  Medio
# 296                        El Cunzato               Italiana   Bajo
# 297                             Crudo           Mediterránea  Medio
# 298              La Lonja Restaurante                Marisco  Medio
# 299  Federica By Chef Oswaldo Sanchez               Italiana  Medio
#
#            opinion                                    reseña  \
# 290  192 opiniones                 Auténtica comida italiana
# 291   54 opiniones               Cocina mexicana con cariño.
# 292   40 opiniones                    Comida grupo fenomenal
# 293  163 opiniones                                 Buenísimo
# 294  136 opiniones                      Una pena, se alquila
# 295   35 opiniones                             Para repetir.
# 296   31 opiniones                     ¡Gran descubrimiento!
# 297   13 opiniones                          Muy recomendable
# 298  550 opiniones  Agradable sitio en un lugar privilegiado
# 299   72 opiniones                                 BUENÍSIMO
#
#                                     ubicacion        lat      long
# 290        C. de Ríos Rosas, 52, 28003 Madrid  40.441532 -3.695822
# 291            C. de la Pasa, 4, 28005 Madrid   40.41429 -3.708957
# 292
# 293   C. de Agustín de Foxá, 27, 28036 Madrid  40.470799 -3.685203
# 294       C. de Embajadores, 65, 28012 Madrid  40.403922 -3.701303
# 295  Calle de Diego de León, 26, 28006 Madrid  40.434534 -3.682571
# 296        C. de Sta. Isabel, 5, 28012 Madrid  40.411732 -3.698477
# 297
# 298
# 299

# %%
restaurantes.to_csv('../datos/rest_clean.csv', index=False, encoding='utf-8')
