Restaurante: That's Amore, Ubicación: C. de Pelayo, 6, 28004 Madrid
Restaurante: Alduccio, Ubicación: Av. de Concha Espina, 8, 28036 Madrid
Restaurante: Restaurante La Vanduca, Ubicación: C. de Columela, 2, 28001 Madrid
Restaurante: Pans & Company, Ubicación: None
Restaurante: Trattoria In Crescendo, Ubicación: C. de Jaime el Conquistador, 31, 28045 Madrid
Restaurante: Fasfú Burguers, Ubicación: C. de San Marcos, 24, 28004 Madrid
Restaurante: MEGU, Ubicación: Tr.ª de San Isidoro de Sevilla, 28, 28005 Madrid
Restaurante: Fratelli d'italia Lavapiés, Ubicación: C. del Sombrerete, 1, 28012 Madrid
Restaurante: La Taberna de Francesco, Ubicación: C. de Ríos Rosas, 53, 28003 Madrid
Restaurante: Bowlers Kitchen, Ubicación: None
Restaurante: El Brasero de Don Pedro, Ubicación: Av. de Aragón, 358, 28022 Madrid
Restaurante: nonsolocaffé, Ubicación: C. de Ríos Rosas, 52, 28003 Madrid
Restaurante: Solito Taqueria, Ubicación: C. de la Pasa, 4, 28005 Madrid
Restaurante: Restaurante La Rita, Ubicación: None
Restaurante: Asia Te, Ubicación: C. de Agustín de Foxá, 27, 28036 Madrid
Restaurante: Diaz y Larrouy, Ubicación: C. de Embajadores, 65, 28012 Madrid
Restaurante: Mad by Robleño, Ubicación: Calle de Diego de León, 26, 28006 Madrid
Restaurante: El Cunzato, Ubicación: C. de Sta. Isabel, 5, 28012 Madrid
Restaurante: Crudo, Ubicación: None
Restaurante: La Lonja Restaurante, Ubicación: None
Restaurante: Federica By Chef Oswaldo Sanchez, Ubicación: None"""

# %%
type(string)
# Out:
# str

# %%
string.split("Restaurante: ")
# Out:
# ['',
#  'Yakiniku Rikyu, Ubicación: P.º de la Castellana, 15, 28046 Madrid\n',
#  'marmitón, Ubicación: C. de las Aguas, 6, 28005 Madrid\n',
#  'Vinoteca Moratín, Ubicación: C. de Moratín, 36, 28014 Madrid\n',
#  'Pilar Akaneya, Ubicación: C. de Espronceda, 33, 28003 Madrid\n',
#  'Gioia, Ubicación: C. de San Bartolomé, 23, 28004 Madrid\n',
#  'Noi Ristorante, Ubicación: C. de Recoletos, 6, 28001 Madrid\n',
#  'Mudrá Plant Based Recoletos, Ubicación: C. de Recoletos, 13, 28001 Madrid\n',
#  'La MaMá Restaurante, Ubicación: 6 bis, Parque, Av. de Brasil, 28020 Madrid\n',
#  'Sisapo, Ubicación: C. de Trafalgar, 14, 28010 Madrid\n',
#  'RECREO Espartinas, Ubicación: C. de Espartinas, Nº 5, 28001 Madrid\n',
#  'Miyama, Ubicación: None\n',
#  'Deessa, Ubicación: Pl. de la Lealtad, 5, 28014 Madrid\n',
#  'Hotaru Madrid, Ubicación: C. de Alcalá, 99, 28009 Madrid\n',
#  'Yugo the Bunker, Ubicación: Calle de San Blas, 4, 28014 Madrid\n',
#  'Coque, Ubicación: None\n',
# ...

# %%
texto = "'Federica By Chef Oswaldo Sanchez, Ubicación: None'"
len(texto.split("Ubicación"))
# Out:
# 2

# %%
filas = string.split('\n')

restaurantes = {}    # Creo un diccionario para almacenar los datos

for fila in filas:
    
    resto_info = fila.split("Restaurante: ")
    
    if len(resto_info) > 1:
        # Obtener nombre del restaurante y la ubicación
        nombre_restaurante, ubicacion_raw = resto_info[1].split("Ubicación: ")
        
        # Limpiar la ubicación
        ubicacion = ubicacion_raw.strip()
        
        # Agregar al diccionario
        restaurantes[nombre_restaurante.strip()] = ubicacion

# Imprimir el diccionario resultante
print(restaurantes)
# Out:
# {'Yakiniku Rikyu,': 'P.º de la Castellana, 15, 28046 Madrid', 'marmitón,': 'C. de las Aguas, 6, 28005 Madrid', 'Vinoteca Moratín,': 'C. de Moratín, 36, 28014 Madrid', 'Pilar Akaneya,': 'C. de Espronceda, 33, 28003 Madrid', 'Gioia,': 'C. de San Bartolomé, 23, 28004 Madrid', 'Noi Ristorante,': 'C. de Recoletos, 6, 28001 Madrid', 'Mudrá Plant Based Recoletos,': 'C. de Recoletos, 13, 28001 Madrid', 'La MaMá Restaurante,': '6 bis, Parque, Av. de Brasil, 28020 Madrid', 'Sisapo,': 'C. de Trafalgar, 14, 28010 Madrid', 'RECREO Espartinas,': 'C. de Espartinas, Nº 5, 28001 Madrid', 'Miyama,': 'None', 'Deessa,': 'Pl. de la Lealtad, 5, 28014 Madrid', 'Hotaru Madrid,': 'C. de Alcalá, 99, 28009 Madrid', 'Yugo the Bunker,': 'Calle de San Blas, 4, 28014 Madrid', 'Coque,': 'None', 'El pedrusco de Aldealcorvo,': 'C. de Juan de Austria, 27, 28010 Madrid', 'KABUKI WELLINGTON SL,': 'C. de Velázquez, 6, 28001 Madrid', 'Kabuki,': 'None', 'Restaurante Lakasa,': 'Pl. del Descubridor Diego de Ordás, 1, 28003 M
# ...

# %%
type(restaurantes)
# Out:
# dict

# %%
restaurantes
# Out:
# {'Yakiniku Rikyu,': 'P.º de la Castellana, 15, 28046 Madrid',
#  'marmitón,': 'C. de las Aguas, 6, 28005 Madrid',
#  'Vinoteca Moratín,': 'C. de Moratín, 36, 28014 Madrid',
#  'Pilar Akaneya,': 'C. de Espronceda, 33, 28003 Madrid',
#  'Gioia,': 'C. de San Bartolomé, 23, 28004 Madrid',
#  'Noi Ristorante,': 'C. de Recoletos, 6, 28001 Madrid',
#  'Mudrá Plant Based Recoletos,': 'C. de Recoletos, 13, 28001 Madrid',
#  'La MaMá Restaurante,': '6 bis, Parque, Av. de Brasil, 28020 Madrid',
#  'Sisapo,': 'C. de Trafalgar, 14, 28010 Madrid',
#  'RECREO Espartinas,': 'C. de Espartinas, Nº 5, 28001 Madrid',
#  'Miyama,': 'None',
#  'Deessa,': 'Pl. de la Lealtad, 5, 28014 Madrid',
#  'Hotaru Madrid,': 'C. de Alcalá, 99, 28009 Madrid',
#  'Yugo the Bunker,': 'Calle de San Blas, 4, 28014 Madrid',
#  'Coque,': 'None',
#  'El pedrusco de Aldealcorvo,': 'C. de Juan de Austria, 27, 28010 Madrid',
#  'KABUKI WELLINGTON SL,': 'C. de Velázquez, 6, 28001 Madrid',
#  'Kabuki,': 'None',
# ...

# %%
df_restaurantes = pd.DataFrame(list(restaurantes.items()), columns=['restaurante', 'ubicacion'])

# %%
df_restaurantes['restaurante'] = df_restaurantes['restaurante'].str.rstrip(',')

# %%
df_restaurantes.head()
# Out:
#         restaurante                               ubicacion
# 0    Yakiniku Rikyu  P.º de la Castellana, 15, 28046 Madrid
# 1          marmitón        C. de las Aguas, 6, 28005 Madrid
# 2  Vinoteca Moratín         C. de Moratín, 36, 28014 Madrid
# 3     Pilar Akaneya      C. de Espronceda, 33, 28003 Madrid
# 4             Gioia   C. de San Bartolomé, 23, 28004 Madrid

# %%
len(df_restaurantes)
# Out:
# 295

# %%
df_restaurantes["Lat&Lon"] ="loque sea"

# %%
df_restaurantes
# Out:
#                           restaurante  \
# 0                      Yakiniku Rikyu
# 1                            marmitón
# 2                    Vinoteca Moratín
# 3                       Pilar Akaneya
# 4                               Gioia
# ..                                ...
# 290                    Mad by Robleño
# 291                        El Cunzato
# 292                             Crudo
# 293              La Lonja Restaurante
# 294  Federica By Chef Oswaldo Sanchez
#
#                                     ubicacion    Lat&Lon
# 0      P.º de la Castellana, 15, 28046 Madrid  loque sea
# 1            C. de las Aguas, 6, 28005 Madrid  loque sea
# 2             C. de Moratín, 36, 28014 Madrid  loque sea
# 3          C. de Espronceda, 33, 28003 Madrid  loque sea
# 4       C. de San Bartolomé, 23, 28004 Madrid  loque sea
# ..                                        ...        ...
# 290  Calle de Diego de León, 26, 28006 Madrid  loque sea
# ...

# %%
df_restaurantes.ubicacion[0]
# Out:
# 'P.º de la Castellana, 15, 28046 Madrid'

# %%
x = 'P.º de la Castellana, 15, 28046 Madrid'

# %%
from geopy.geocoders import Nominatim

def obtener_coordenadas(direccion):
    """
    Obtiene las coordenadas (latitud y longitud) a partir de una dirección.

    Parameters:
    - direccion (str): Dirección que incluye la calle y el número.

    Returns:
    - Tuple[float, float]: Tupla con la latitud y longitud.
    """
    geolocalizador = Nominatim(user_agent="mi_aplicacion_geopy")
    ubicacion = geolocalizador.geocode(direccion)

    if ubicacion:
        latitud, longitud = ubicacion.latitude, ubicacion.longitude
        return latitud, longitud
    else:
        print(f"No se pudo obtener la ubicación para la dirección: {direccion}")

# %%
obtener_coordenadas(x)
# Out:
# (40.4280979, -3.690173)

# %%
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
import time

def obtener_coordenadas(direccion):
    """
    Obtiene las coordenadas (latitud y longitud) a partir de una dirección.

    Parameters:
    - direccion (str): Dirección que incluye la calle y el número.

    Returns:
    - Tuple[float, float]: Tupla con la latitud y longitud.
    """
    geolocalizador = Nominatim(user_agent="mi_aplicacion_geopy")

    intentos = 0
    while intentos < 3:
        try:
            ubicacion = geolocalizador.geocode(direccion)
            if ubicacion:
                latitud, longitud = ubicacion.latitude, ubicacion.longitude
                return latitud, longitud
            else:
                print(f"No se pudo obtener la ubicación para la dirección: {direccion}")
                return None
        except (GeocoderTimedOut, GeocoderUnavailable) as e:
            print(f"Error: {e}. Intentando de nuevo...")
            time.sleep(2)
            intentos += 1

    print(f"No se pudo obtener la ubicación para la dirección: {direccion}")
    return None

# %%
df_restaurantes["Lat&Lon"] = df_restaurantes["ubicacion"].apply(obtener_coordenadas)
# Out:
# Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6+bis%2C+Parque%2C+Av.+de+Brasil%2C+28020+Madrid&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")). Intentando de nuevo...
# Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6+bis%2C+Parque%2C+Av.+de+Brasil%2C+28020+Madrid&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")). Intentando de nuevo...
# ...

# %%
df_restaurantes.tail(20)
# Out:
#                           restaurante  \
# 275                          Alduccio
# 276            Restaurante La Vanduca
# 277                    Pans & Company
# 278            Trattoria In Crescendo
# 279                    Fasfú Burguers
# 280                              MEGU
# 281        Fratelli d'italia Lavapiés
# 282           La Taberna de Francesco
# 283                   Bowlers Kitchen
# 284           El Brasero de Don Pedro
# 285                      nonsolocaffé
# 286                   Solito Taqueria
# 287               Restaurante La Rita
# 288                           Asia Te
# 289                    Diaz y Larrouy
# 290                    Mad by Robleño
# 291                        El Cunzato
# 292                             Crudo
# 293              La Lonja Restaurante
# 294  Federica By Chef Oswaldo Sanchez
#
#                                             ubicacion  \
# 275             Av. de Concha Espina, 8, 28036 Madrid
# ...

# %%
# Filtrar las filas con valores nulos en la columna "ubicacion"
df_restaurantes.head()
# Out:
#         restaurante                               ubicacion  \
# 0    Yakiniku Rikyu  P.º de la Castellana, 15, 28046 Madrid
# 1          marmitón        C. de las Aguas, 6, 28005 Madrid
# 2  Vinoteca Moratín         C. de Moratín, 36, 28014 Madrid
# 3     Pilar Akaneya      C. de Espronceda, 33, 28003 Madrid
# 4             Gioia   C. de San Bartolomé, 23, 28004 Madrid
#
#                                      Lat&Lon
# 0                    (40.4280979, -3.690173)
# 1           (40.4108219, -3.712107746868964)
# 2  (40.412472050000005, -3.6954412113077497)
# 3                    (40.4405573, -3.696109)
# 4                   (40.4221651, -3.6983792)

# %%
# Filtrar las filas con valores nulos en la columna "Lat&Lon"
lat_lon_none = df_restaurantes[df_restaurantes["Lat&Lon"].isnull()]
lat_lon_none
# Out:
#                          restaurante  \
# 7                La MaMá Restaurante
# 9                  RECREO Espartinas
# 25                 Brunchit Malasaña
# 26                      Ouh...Babbo!
# 43       Gourmet Experience Gran Vía
# 55          Fiaschetteria La Saletta
# 86                            Cromia
# 118                       Sazón-arte
# 120           Rioko Nikkei Sushi Bar
# 128   Oven mozzarella Bar Las Tablas
# 133  Hddn Premium Mixology & Cuisine
# 135   RESTAURANTE DOLCE VITA COSLADA
# 142                Camino Sacramento
# 144                     GastroVía 61
# 171                   Divina Dolores
# 176                     WelkhomeClub
# 194             Trattoria da Alfredo
# 198                 The Spanish Farm
# 208   La Taberna de Mister Pinkleton
# 226                       Asian Army
# 228                      Sr. Ito Lab
# 233                     Don Giovanni
# 235          La Pulpería De Victoria
# 251                Trattoria Adriana
# ...

# %%
# No tenemos informacion de la ubicacion exacta de al menos 75 restaurantes. 

none = df_restaurantes[df_restaurantes["ubicacion"] == 'None'].count()
none
# Out:
# restaurante    75
# ubicacion      75
# Lat&Lon        75
# dtype: int64

# %%
# No tenemos informacion de la longitud y latitud exacta de 29 restaurantes más, a pesar de si tener su ubicacion. 

lat_lon_none.count()
# Out:
# restaurante    29
# ubicacion      29
# Lat&Lon         0
# dtype: int64

# %%
df_restaurantes.to_csv('../datos/ubica_rest.csv', index=False, encoding='utf-8')

# %% [markdown]
# Con la informacion que tengo trataré ahora de unir los df, a través de un merge -> hecho en el notebook: Uniones (dentro de restaurantes)
